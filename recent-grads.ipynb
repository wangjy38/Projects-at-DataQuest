# %%
import pandas as pd 
# %matplotlib inline

# %%
recent_grads=pd.read_csv("recent-grads.csv")
recent_grads.head(5)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count=recent_grads.shape[0]
recent_grads=recent_grads.dropna()
cleaned_data_count=recent_grads.shape[0]
print (raw_data_count,cleaned_data_count)
# Out:
# 173 172

# %%
ax1 = recent_grads.plot(x='Sample_size', y='Employed', kind='scatter')
ax1.set_title('Employed vs. Sample_size')

# %%
ax2 = recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
ax2.set_title('Median vs. Sample_size')

# %%
ax3 = recent_grads.plot(x='Full_time', y='Median', kind='scatter')
ax3.set_title('Median vs. Full_time')

# %%
ax4 = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')
ax4.set_title('Unemployment_rate vs. ShareWomen')

# %%
ax5 = recent_grads.plot(x='Men', y='Median', kind='scatter')
ax5.set_title('Median vs. Men')

# %%
ax6 = recent_grads.plot(x='Women', y='Median', kind='scatter')
ax6.set_title('Median vs. Women')

# %%
ax7 = recent_grads.plot(x='Total', y='Median', kind='scatter')
ax7.set_title('Median vs. Total')

# %% [markdown]
# Students in more popular major do not make more money

# %%
ax8 = recent_grads.plot(x='ShareWomen', y='Median', kind='scatter')
ax8.set_title('Median vs. ShareWomen')

# %% [markdown]
# Students that majored in subjects that were majority female do not make more money

# %%
ax8 = recent_grads.plot(x='Employed', y='Median', kind='scatter')
ax8.set_title('Median vs. Employed')

# %%
ax8 = recent_grads.plot(x='Full_time_year_round', y='Median', kind='scatter')
ax8.set_title('Median vs. Full_time_year_round')

# %% [markdown]
# No relationship between Median salary and number of full time employees

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Median'].plot(kind='hist')

# %% [markdown]
# 30000-40000 is the most common median salary range

# %%
recent_grads['Employed'].plot(kind='hist')

# %%
recent_grads['Full_time'].plot(kind='hist')

# %%
recent_grads['ShareWomen'].plot(kind='hist')

# %%
recent_grads['Unemployment_rate'].plot(kind='hist')

# %%
recent_grads['Men'].plot(kind='hist')

# %%
recent_grads['Women'].plot(kind='hist')

# %%
ax10=recent_grads['ShareWomen'].hist(range=(0,1), bins=2)
ax10.set_title("Woman's Share")

# %% [markdown]
# Around 40% of majors are predomintly male, 60% of majors are predomintly female.

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[["Sample_size", "Median"]], figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd9f054668>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcd6d2c1518>]], dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size", "Median", "Unemployment_rate"]], figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd6d26a550>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcd6cfba588>]], dtype=object)

# %%
recent_grads[:5]['Women'].plot(kind='bar')

# %%
recent_grads[:5].plot.bar(x='Major', y='Women')

# %%
Lowest_ShareWoman_majors=recent_grads.sort_values("ShareWomen").head(10)["Major"]
Highest_ShareWoman_majors=recent_grads.sort_values("ShareWomen", ascending=False).head(10)["Major"]

# %%
ax11=recent_grads[recent_grads["Major"].isin(Lowest_ShareWoman_majors)].plot.bar(x="Major", y="ShareWomen")
ax11.set_title("ShareWomen in 10 lowest paying majors")
ax11.set_ylim(0,1)
# Out:
# (0, 1)

# %%
ax12=recent_grads[recent_grads["Major"].isin(Highest_ShareWoman_majors)].plot.bar(x="Major", y="ShareWomen")
ax12.set_title("ShareWomen in 10 highest paying majors")

# %%
ax13=recent_grads[recent_grads["Major"].isin(Lowest_ShareWoman_majors)].plot.bar(x="Major", y="Unemployment_rate")
ax13.set_title("Unemployment_rate in 10 lowest paying majors")
ax13.set_ylim(0,0.15)
# Out:
# (0, 0.15)

# %%
ax14=recent_grads[recent_grads["Major"].isin(Highest_ShareWoman_majors)].plot.bar(x="Major", y="Unemployment_rate")
ax14.set_title("Unemployment_rate in 10 highest paying majors")
ax14.set_ylim(0,0.15)
# Out:
# (0, 0.15)
